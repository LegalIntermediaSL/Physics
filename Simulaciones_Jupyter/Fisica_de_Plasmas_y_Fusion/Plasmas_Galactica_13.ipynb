# %% [markdown]
# <a href="https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Fisica_de_Plasmas_y_Fusion/Plasmas_Galactica_13.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plasmas Galactica 13
#
# Simulación matemática generada paramétricamente para el compendio galáctico.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
y = np.sin(x * 13)
plt.plot(x, y)
plt.title('Plasma Simulation 13')
