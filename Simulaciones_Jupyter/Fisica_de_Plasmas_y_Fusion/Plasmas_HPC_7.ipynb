# %% [markdown]
# <a href="https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Fisica_de_Plasmas_y_Fusion/Plasmas_HPC_7.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Supercomputación: Plasmas HPC 7
#
# Simulación computacional de altísimo rendimiento (HPC) orientada a sistemas ultracomplejos.

# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
def fokker():
    f = np.exp(-np.linspace(-5,5,100)**2)
    plt.plot(f); plt.savefig("fokker.png")
if __name__=="__main__": fokker()
