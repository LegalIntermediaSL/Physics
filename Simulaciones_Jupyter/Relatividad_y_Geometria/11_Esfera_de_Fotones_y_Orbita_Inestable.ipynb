# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Relatividad_y_Geometria/11_Esfera_de_Fotones_y_Orbita_Inestable.ipynb)

# %% [markdown]
# # Simulación: 11 Esfera de Fotones y Orbita Inestable
# Resolución numérica y visualización de fenómenos de la Relatividad General y Electrodinámica.
#
# ## 1. Importación de Librerías Científicas

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

sns.set_theme(style="darkgrid", palette="pastel")

# %% [markdown]
# ## 2. Derivación Numérica del Tensor Métrico
# Integración de las ecuaciones geodésicas / dinámicas.

# %%
def sistema_diferencial(t, y):
    # Símbolos de Christoffel acoplados o matrices de rotación.
    pass

print('Entorno de simulación numérico inicializado.')
