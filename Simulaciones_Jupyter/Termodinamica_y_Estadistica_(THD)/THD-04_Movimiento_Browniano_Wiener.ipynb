# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Termodinamica_y_Estadistica_%28THD%29/THD-04_Movimiento_Browniano_Wiener.ipynb)

# %% [markdown]
# # Movimiento Browniano (Proceso de Wiener)
#
# Simulación estocástica de trayectorias aleatorias en 2D.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

n_steps = 1000
dx = np.random.randn(n_steps)
dy = np.random.randn(n_steps)
x = np.cumsum(dx)
y = np.cumsum(dy)

plt.figure(figsize=(6,6))
plt.plot(x, y, lw=0.5, color='orange')
plt.title('Trayectoria de Partícula en Movimiento Browniano')
plt.axis('equal')
plt.grid(True)
plt.show()
