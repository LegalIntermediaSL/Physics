# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Proyectos_de_Supercomputacion/Nuclear_HPC_4.ipynb)

# %% [markdown]
# # Supercomputación: Nuclear HPC 4
#
# Simulación computacional de altísimo rendimiento (HPC) orientada a sistemas ultracomplejos.

# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
def liquid_drop():
    A = np.arange(1, 250)
    E = 15.67*A - 17.23*A**(2/3)
    plt.plot(A, E); plt.savefig("liquid.png")
if __name__=="__main__": liquid_drop()
