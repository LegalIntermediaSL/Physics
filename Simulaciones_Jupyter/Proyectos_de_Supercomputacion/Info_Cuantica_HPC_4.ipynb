# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/legalintermedia/Physics/blob/main/Simulaciones_Jupyter/Proyectos_de_Supercomputacion/Info_Cuantica_HPC_4.ipynb)

# %% [markdown]
# # Supercomputación: Info Cuantica HPC 4
#
# Simulación computacional de altísimo rendimiento (HPC) orientada a sistemas ultracomplejos.

# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
def q_walk():
    pos = np.zeros(100); pos[50] = 1
    plt.plot(pos); plt.savefig("qwalk.png")
if __name__=="__main__": q_walk()
