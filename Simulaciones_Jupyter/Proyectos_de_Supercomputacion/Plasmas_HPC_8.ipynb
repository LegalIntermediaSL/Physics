# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Proyectos_de_Supercomputacion/Plasmas_HPC_8.ipynb)

# %% [markdown]
# # Supercomputación: Plasmas HPC 8
#
# Simulación computacional de altísimo rendimiento (HPC) orientada a sistemas ultracomplejos.

# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
def reconnection():
    B = np.meshgrid(np.linspace(-1,1,20), np.linspace(-1,1,20))
    plt.streamplot(B[0], B[1], B[1], B[0]); plt.savefig("recon.png")
if __name__=="__main__": reconnection()
