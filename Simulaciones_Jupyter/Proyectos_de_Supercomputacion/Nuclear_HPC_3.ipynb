# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/legalintermedia/Physics/blob/main/Simulaciones_Jupyter/Proyectos_de_Supercomputacion/Nuclear_HPC_3.ipynb)

# %% [markdown]
# # Supercomputación: Nuclear HPC 3
#
# Simulación computacional de altísimo rendimiento (HPC) orientada a sistemas ultracomplejos.

# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
def shell_model():
    levels = [2, 8, 20, 28, 50, 82, 126]
    plt.plot(levels, 'o'); plt.savefig("shell.png")
if __name__=="__main__": shell_model()
