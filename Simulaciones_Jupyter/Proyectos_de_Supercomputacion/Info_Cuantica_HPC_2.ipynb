# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Proyectos_de_Supercomputacion/Info_Cuantica_HPC_2.ipynb)

# %% [markdown]
# # Supercomputación: Info Cuantica HPC 2
#
# Simulación computacional de altísimo rendimiento (HPC) orientada a sistemas ultracomplejos.

# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
def rep_code():
    state = np.zeros(5)
    plt.bar(range(5), state); plt.savefig("rep.png")
if __name__=="__main__": rep_code()
