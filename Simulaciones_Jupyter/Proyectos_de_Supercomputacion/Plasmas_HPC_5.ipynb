# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/legalintermedia/Physics/blob/main/Simulaciones_Jupyter/Proyectos_de_Supercomputacion/Plasmas_HPC_5.ipynb)

# %% [markdown]
# # Supercomputación: Plasmas HPC 5
#
# Simulación computacional de altísimo rendimiento (HPC) orientada a sistemas ultracomplejos.

# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
def lwfa():
    x = np.linspace(0,10,100)
    E = np.sin(x)*np.exp(-0.1*x)
    plt.plot(x, E); plt.savefig("lwfa.png")
if __name__=="__main__": lwfa()
