# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Teoria_General_%28Jupyter.gen%29/Teoria_General_%28%28Jupyter.gen.gen%29/COS-10_Automata_Celular_Emergencia_Vida.ipynb)

# %% [markdown]
# # Surgimiento Computacional (Juego de la Vida)
#
# Demostración de cómo la complejidad macroscópica biológica/física surge de reglas algorítmicas deterministas a nivel de bit.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

N = 50
grid = np.random.choice([0, 1], size=(N,N), p=[0.8, 0.2])

fig, ax = plt.subplots(figsize=(6,6))
mat = ax.matshow(grid, cmap='binary')
plt.title('El Juego de la Vida de Conway (Matriz de Bits)')
plt.axis('off')

# Mostramos el frame inicial en el notebook estático
plt.show()

# Nota: Para animar en colab localmente:
'''
def update(data):
    global grid
    newGrid = grid.copy()
    for i in range(N):
        for j in range(N):
            total = int((grid[i, (j-1)%N] + grid[i, (j+1)%N] +
                         grid[(i-1)%N, j] + grid[(i+1)%N, j] +
                         grid[(i-1)%N, (j-1)%N] + grid[(i-1)%N, (j+1)%N] +
                         grid[(i+1)%N, (j-1)%N] + grid[(i+1)%N, (j+1)%N]))
            if grid[i, j] == 1:
                if (total < 2) or (total > 3): newGrid[i, j] = 0
            else:
                if total == 3: newGrid[i, j] = 1
    mat.set_data(newGrid)
    grid = newGrid
    return [mat]
ani = animation.FuncAnimation(fig, update, interval=50, frames=100)
HTML(ani.to_jshtml())
'''
