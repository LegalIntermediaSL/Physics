# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Fluidos_y_Medios_Continuos/FLD-13_Elasticidad_de_Materiales_Simulacion.ipynb)

# %% [markdown]
# # Simulación Computacional: Elasticidad de Materiales
# **Área:** Fluidos y Medios Continuos
#
# Este cuaderno interactivo de Jupyter ejecuta numéricamente los modelos físicos descritos en el repositorio. Puedes modificar los parámetros iniciales y ejecutar las celdas para visualizar gráficos o animaciones interactivos.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# Ecuación diferencial de la elástica: E*I*y'' = M(x)
# Para una viga en voladizo con carga uniforme q: M(x) = -q*(L-x)^2 / 2

L = 5.0        # Longitud de la viga (m)
E = 200e9      # Módulo de Young (Pa) - Acero
I = 1e-5       # Inercia de la sección transversal (m^4)
q = 10000      # Carga distribuida (N/m)

x = np.linspace(0, L, 100)
# Integración analítica:
# y(x) = (-q*x^2 / (24*E*I)) * (x^2 - 4*L*x + 6*L^2)
deflection = (-q * x**2 / (24 * E * I)) * (x**2 - 4 * L * x + 6 * L**2)

plt.figure(figsize=(10, 4))
plt.plot(x, deflection * 1000, 'b-', lw=3) # Convertido a mm
plt.fill_between(x, deflection * 1000, 0, color='blue', alpha=0.1)
plt.axhline(0, color='black', linestyle='--')
plt.title("Línea Elástica de Deflexión (Viga en Voladizo)")
plt.xlabel("Longitud x (m)")
plt.ylabel("Deflexión (mm)")
plt.grid(True)
plt.show()
