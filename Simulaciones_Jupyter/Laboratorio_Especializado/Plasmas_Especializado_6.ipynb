# %% [markdown]
# <a href="https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Laboratorio_Especializado/Plasmas_Especializado_6.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio Especializado: Plasmas Especializado 6
#
# Simulación computacional ultra-avanzada correspondiente a la literatura científica extendida (Nivel Experto).

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def mhd_alfven():
    x = np.linspace(0, 4*np.pi, 100)
    t = 1.0
    vA = 2.0
    B_pert = np.sin(x - vA * t)
    plt.plot(x, B_pert)
    plt.title('MHD Alfven Wave')
    plt.xlabel('x')
    plt.ylabel('B_pert')
    plt.savefig('alfven.png')

if __name__ == "__main__":
    mhd_alfven()
