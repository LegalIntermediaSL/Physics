# %% [markdown]
# <a href="https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Electromagnetismo/Electromagnetismo_Compendio_14.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Compendio Subtemático: Electromagnetismo Compendio 14
#
# Simulación computacional para el compendio a escala industrial de físicas avanzadas.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def main():
    t = np.linspace(0, 0.1, 500)
    f = 50.0
    omega = 2*np.pi*f
    V0 = 10.0
    R = 5.0
    V = V0 * np.sin(omega*t)
    I = V / R
    plt.plot(t, V, label='Voltage (V)')
    plt.plot(t, I, label='Current (A)')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.title("14. AC Circuit with Resistor (In Phase)")
    plt.legend()
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
