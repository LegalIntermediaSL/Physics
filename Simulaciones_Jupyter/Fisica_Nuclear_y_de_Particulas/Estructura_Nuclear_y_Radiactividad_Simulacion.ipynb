# %% [markdown]
# <a href="https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Fisica_Nuclear_y_de_Particulas/Estructura_Nuclear_y_Radiactividad_Simulacion.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulación Computacional: Estructura Nuclear y Radiactividad
# **Área:** Fisica Nuclear y de Particulas
#
# Este cuaderno interactivo de Jupyter ejecuta numéricamente los modelos físicos descritos en el repositorio. Puedes modificar los parámetros iniciales y ejecutar las celdas para visualizar gráficos o animaciones interactivos.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# Constantes de desintegración (1/s)
lambda_A = 0.1   # Núcleo padre decae rápido
lambda_B = 0.05  # Núcleo hijo decae más lento

def decay_chain(y, t):
    N_A, N_B, N_C = y
    dN_A_dt = -lambda_A * N_A
    dN_B_dt = lambda_A * N_A - lambda_B * N_B
    dN_C_dt = lambda_B * N_B
    return [dN_A_dt, dN_B_dt, dN_C_dt]

# Condiciones iniciales: 100% de A
y0 = [100.0, 0.0, 0.0]
t = np.linspace(0, 100, 500)

sol = odeint(decay_chain, y0, t)

plt.figure(figsize=(10, 6))
plt.plot(t, sol[:, 0], 'r', linewidth=2, label='Núcleo A (Padre)')
plt.plot(t, sol[:, 1], 'g', linewidth=2, label='Núcleo B (Hijo)')
plt.plot(t, sol[:, 2], 'b', linewidth=2, label='Núcleo C (Nieto, Estable)')

plt.title('Simulación de la Cadena de Desintegración Radiactiva')
plt.xlabel('Tiempo (s)')
plt.ylabel('Población (%)')
plt.legend(loc='best')
plt.grid(True)
plt.show()
