# %% [markdown]
# <a href="https://colab.research.google.com/github/LegalIntermediaSL/Physics/blob/main/Simulaciones_Jupyter/Fisica_Nuclear_y_de_Particulas/Fisica_Nuclear_Galactica_46.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fisica Nuclear Galactica 46
#
# Simulación matemática generada paramétricamente para el compendio galáctico.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# Physics simulation 46
t = np.linspace(0, 10, 100)
plt.plot(np.cos(t*46), np.sin(t*46))
plt.title('Galactic Nuclear Physics 46')
